# %%
import numpy as np
import corner as DFM

# %%
# --- plotting --- 
import corner as DFM
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False

# %%
wave = np.load('/Users/chahah/data/provabgs/wave_fsps.npy')
theta = np.load('/Users/chahah/data/provabgs/fsps.burst.theta.test.npy')
lnflux = np.load('/Users/chahah/data/provabgs/fsps.burst.lnspectrum.test.npy')

# %%
tburst = theta[:,6]

# %%
low_flux = (np.min(lnflux, axis=1) < -100)

# %%
tburst[low_flux].min()
# Out:
# 13.275581923062374

# %%
fig = DFM.corner(theta[:,6:])
_ = DFM.corner(theta[low_flux,6:], color='C1', fig=fig)

# %%
fig = plt.figure(figsize=(10,5))
sub = fig.add_subplot(111)
for lnf in lnflux[::1000]: 
    sub.plot(wave, lnf, c='k')

for lnf in lnflux[(tburst > 13.27),:]:
    sub.plot(wave, lnf, c='C1', alpha=0.5)
sub.set_xlim(2e3, 1e4)
sub.set_ylim(-140, None)
# Out:
# (-140.0, -0.3533127422857003)

# %%
fig = plt.figure(figsize=(10,5))
sub = fig.add_subplot(111)
for lnf in lnflux[(tburst <13.27),:][::10]:
    sub.plot(wave, lnf, c='k')
sub.set_xlim(2e3, 1e4)
sub.set_ylim(-140, None)
# Out:
# (-140.0, -2.6646672574006196)
